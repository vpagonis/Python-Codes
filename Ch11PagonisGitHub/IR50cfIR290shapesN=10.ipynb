# %% [markdown]
# <a href="https://colab.research.google.com/github/vpagonis/Python-Codes/blob/main/Ch11PagonisGitHub/IR50cfIR290shapesN%3D10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tunisia CW-IRSL 290oC  data fitted with KP-CW equation
from scipy import optimize
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
from prettytable import PrettyTable 
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

url='https://github.com/vpagonis/Python-Codes/raw/main/Ch11PagonisGitHub/IR50LandTallpos.TXT'
df =pd.read_table(url,delimiter='\t')
rhos, drhos, As ,dAs =[0]*df.shape[1],[0]*df.shape[1],[0]*df.shape[1],[0]*df.shape[1]
x=[[0]*len(x_data)]*df.shape[1]
y=[[0]*len(x_data)]*df.shape[1] 

for i in range(1,10,1):
    x_data,y_data = df.iloc[:, 0].to_numpy(), df.iloc[:, i].to_numpy()   
    if (max(y_data)>200):
       x[i],y[i]=x_data, y_data/max(y_data)
    plt.plot(np.log(x[i]),y[i]) 

for i in range(1,10,1):
    x_data,y_data = df.iloc[:, 0].to_numpy(), df.iloc[:, i].to_numpy()   
    if (max(y_data)>200):
       x[i],y[i]=x_data, (y_data-y_data[-1])/max(y_data-y_data[-1])
    plt.plot(np.log(x[i]),y[i]) 


url='https://github.com/vpagonis/Python-Codes/raw/main/Ch11PagonisGitHub/IR290LandTallpos.TXT'
df =pd.read_table(url,delimiter='\t')
rhos, drhos, As ,dAs =[0]*df.shape[1],[0]*df.shape[1],[0]*df.shape[1],[0]*df.shape[1]
x=[[0]*len(x_data)]*df.shape[1]
y=[[0]*len(x_data)]*df.shape[1]

for i in range(1,10,1):
    x_data,y_data = df.iloc[:, 0].to_numpy(), df.iloc[:, i].to_numpy()   
    if (max(y_data)>200):
       x[i],y[i]=x_data, y_data/max(y_data)
    plt.plot(np.log(x[i]),y[i]) 

for i in range(1,10,1):
    x_data,y_data = df.iloc[:, 0].to_numpy(), df.iloc[:, i].to_numpy()   
    if (max(y_data)>200):
       x[i],y[i]=x_data, (y_data-y_data[-1])/max(y_data-y_data[-1])
    plt.plot(np.log(x[i]),y[i])
